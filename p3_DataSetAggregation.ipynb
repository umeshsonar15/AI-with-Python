# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/bankloan2.csv')
df.head()
# Out:
#    ID    Amount   Salary   Ratio   Age      Occupation      Property  \
# 0   1    245100    66400    3.69    44      industrial          farm
# 1   2     90600    75300    1.20    41      industrial          farm
# 2   3    195600    52100    3.75    37      industrial          farm
# 3   4    157800    67600    2.33    44      industrial     apartment
# 4   5    150800    35800    4.21    39    professional     apartment
#
#          Type    Outcome
# 0         stb      repay
# 1         stb      repay
# 2         ftb    default
# 3         ftb      repay
# 4         stb    default

# %%
df.aggregate(['sum', 'min','max'])
# Out:
#          ID     Amount     Salary   Ratio     Age  \
# sum   325.0  4486500.0  1480500.0  81.300  909.00
# min     1.0    83000.0    32300.0   1.200   17.00
# max    25.0   284100.0    79700.0   8.800   51.00
# mean   13.0   179460.0    59220.0   3.252   36.36
#
#                                              Occupation  \
# sum     industrial  industrial  industrial  industri...
# min                                          industrial
# max                                        professional
# mean                                                NaN
#
#                                                Property  \
# sum      farm   farm   farm   apartment apartment   ...
# min                                           apartment
# max                                               house
# mean                                                NaN
#
#                                                    Type  \
# sum          stb       stb       ftb  ftb  stb      ...
# ...

# %%
df.aggregate(['average'])
# Out:
#            ID    Amount   Salary   Ratio    Age
# average  13.0  179460.0  59220.0   3.252  36.36

# %%
df.aggregate(['mean'])
# Out:
#         ID    Amount   Salary   Ratio    Age
# mean  13.0  179460.0  59220.0   3.252  36.36

# %%
df.aggregate(['median'])
# Out:
#           ID    Amount   Salary   Ratio   Age
# median  13.0  175200.0  61100.0    3.15  37.0

# %%
df.aggregate(['mode'])
# Out:
#      ID   Amount  Salary  Ratio   Age    Occupation    Property        Type  \
#    mode     mode    mode   mode  mode          mode        mode        mode
# 0     1    83000   32300   3.15  30.0    industrial        farm         ftb
# 1     2    90600   35800    NaN  37.0           NaN         NaN         NaN
# 2     3   112800   39900    NaN  44.0           NaN         NaN         NaN
# 3     4   133000   45300    NaN   NaN           NaN         NaN         NaN
# 4     5   143200   48900    NaN   NaN           NaN         NaN         NaN
# 5     6   149700   49200    NaN   NaN           NaN         NaN         NaN
# 6     7   150800   52100    NaN   NaN           NaN         NaN         NaN
# 7     8   154000   53000    NaN   NaN           NaN         NaN         NaN
# 8     9   157400   53300    NaN   NaN           NaN         NaN         NaN
# 9    10   157800   54200    NaN   NaN           NaN         NaN         NaN
# ...
