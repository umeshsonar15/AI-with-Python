# %%
#Visualizing audio signals

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %%
# Read the audio file
sampling_freq, signal = wavfile.read('/content/drive/MyDrive/file_example_WAV_1MG.wav')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.

# %%
#Print the shape of the signal, the datatype, and the duration of the audio signal:

# Display the params
print('\nSignal shape:', signal.shape)
print('Datatype:', signal.dtype)
print('Signal duration:', round(signal.shape[0] / float(sampling_freq), 2), 'seconds')
# Out:
# Signal shape: (268237, 2)
# Datatype: int16
# Signal duration: 33.53 seconds

# %%
# Normalize the signal
signal = signal / np.power(2, 15)
signal
# Out:
# array([[-3.47900391e-03,  7.01904297e-04],
#        [-7.35473633e-03,  9.15527344e-05],
#        [-8.69750977e-03, -8.85009766e-04],
#        ...,
#        [-2.35595703e-02, -3.23181152e-02],
#        [-1.28784180e-02, -2.56347656e-02],
#        [-2.40173340e-02, -9.58251953e-03]])

# %%
# Extract the first 50 values
signal = signal[:50]
signal
# Out:
# array([[-3.47900391e-03,  7.01904297e-04],
#        [-7.35473633e-03,  9.15527344e-05],
#        [-8.69750977e-03, -8.85009766e-04],
#        [-3.32641602e-03,  1.34277344e-03],
#        [-1.52587891e-03,  3.66210938e-04],
#        [ 2.34985352e-03,  6.10351562e-04],
#        [ 6.01196289e-03,  2.04467773e-03],
#        [ 3.08227539e-03,  3.60107422e-03],
#        [ 3.66210938e-03,  3.02124023e-03],
#        [ 1.73950195e-03, -8.85009766e-04],
#        [ 5.61523438e-03, -7.62939453e-04],
#        [ 1.86157227e-03, -2.31933594e-03],
#        [-2.10571289e-03, -3.57055664e-03],
#        [ 1.49536133e-03, -2.68554688e-03],
#        [-8.54492188e-04, -1.95312500e-03],
#        [-3.75366211e-03,  6.10351562e-04],
#        [-1.77001953e-03, -1.22070312e-03],
#        [-1.03759766e-03, -5.79833984e-04],
#        [-9.76562500e-04,  1.00708008e-03],
#        [-7.62939453e-04,  0.00000000e+00],
#        [-3.35693359e-03,  4.88281250e-04],
#        [-3.17382812e-03, -9.76562500e-04],
#        [-1.34277344e-03,  2.04467773e-03],
#        [-3.35693359e-03,  2.89916992e-03],
#        [-2.50244141e-03,  2.99072266e-03],
#        [-2.22778320e-03,  1.37329102e-03],
#        [-3.38745117e-03, -1.37329102e-03],
#        [-1.92260742e-03,  1.52587891e-04],
#        [ 1.25122070e-03, -1.34277344e-03],
#        [ 4.88281250e-03, -1.86157227e-03],
#        [ 3.90625000e-03, -1.34277344e-03],
#        [ 6.89697266e-03,  1.86157227e-03],
#        [ 9.15527344e-04,  2.28881836e-03],
#        [-1.28173828e-03, -1.40380859e-03],
#        [ 2.47192383e-03, -6.10351562e-05],
#        [ 2.07519531e-03, -1.03759766e-03],
#        [-2.38037109e-03, -3.90625000e-03],
#        [-3.66210938e-04, -2.80761719e-03],
#        [-3.35693359e-03, -3.29589844e-03],
#        [-9.73510742e-03, -2.50244141e-03],
#        [-3.90625000e-03, -7.93457031e-04],
#        [-2.53295898e-03,  3.35693359e-04],
#        [ 6.40869141e-04,  3.96728516e-03],
#        [ 6.71386719e-04,  4.57763672e-03],
#        [ 1.12915039e-03,  3.02124023e-03],
#        [ 1.80053711e-03, -1.00708008e-03],
#        [-1.31225586e-03, -2.13623047e-03],
#        [-7.93457031e-04, -4.57763672e-04],
#        [-7.93457031e-04, -1.43432617e-03],
#        [-1.89208984e-03, -3.41796875e-03]])

# %%
# Construct the time axis in milliseconds
time_axis = 1000 * np.arange(0, len(signal), 1) / float(sampling_freq)
time_axis
# Out:
# array([0.   , 0.125, 0.25 , 0.375, 0.5  , 0.625, 0.75 , 0.875, 1.   ,
#        1.125, 1.25 , 1.375, 1.5  , 1.625, 1.75 , 1.875, 2.   , 2.125,
#        2.25 , 2.375, 2.5  , 2.625, 2.75 , 2.875, 3.   , 3.125, 3.25 ,
#        3.375, 3.5  , 3.625, 3.75 , 3.875, 4.   , 4.125, 4.25 , 4.375,
#        4.5  , 4.625, 4.75 , 4.875, 5.   , 5.125, 5.25 , 5.375, 5.5  ,
#        5.625, 5.75 , 5.875, 6.   , 6.125])

# %%
# Plot the audio signal
plt.plot(time_axis, signal, color='black')
plt.xlabel('Time (milliseconds)')
plt.ylabel('Amplitude')
plt.title('Input audio signal')
plt.show()
