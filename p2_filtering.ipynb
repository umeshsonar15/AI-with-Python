# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/employees.csv')
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-Aug-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  Unnamed: 11  \
# 0  SH_CLERK    2600             -         124             50          NaN
# 1  SH_CLERK    2600             -         124             50          NaN
# 2   AD_ASST    4400             -         101             10          NaN
# 3    MK_MAN   13000             -         100             20          NaN
# 4    MK_REP    6000             -         201             20          NaN
#
#   gender
# 0      f
# 1      m
# 2      f
# 3      m
# 4      f

# %%
df.drop('COMMISSION_PCT',axis=1,inplace=True)

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# ...

# %%
df["gender"]=="m"
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27     True
# 28    False
# 29     True
# 30    False
# 31    False
# 32     True
# 33    False
# 34     True
# 35    False
# 36     True
# 37     True
# 38    False
# 39     True
# 40    False
# 41     True
# 42    False
# 43     True
# 44     True
# 45    False
# 46    False
# 47    False
# 48     True
# 49     True
# Name: gender, dtype: bool

# %%
df["gender"]=="f"
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20     True
# 21    False
# 22     True
# 23    False
# 24     True
# 25    False
# 26     True
# 27    False
# 28     True
# 29    False
# 30     True
# 31     True
# 32    False
# 33     True
# 34    False
# 35     True
# 36    False
# 37    False
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44    False
# 45     True
# 46     True
# 47     True
# 48    False
# 49    False
# Name: gender, dtype: bool

# %%
df[df["gender"]=="m"]
# Out:
#     EMPLOYEE_ID   FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1           199      Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 3           201      Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 5           203        Susan     Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 7           205      Shelley    Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William      Gietz    WGIETZ  515.123.8181  07-Jun-02
# 12          103    Alexander     Hunold   AHUNOLD  590.423.4567  03-Jan-06
# 13          104        Bruce      Ernst    BERNST  590.423.4568  21-May-07
# 14          105        David     Austin   DAUSTIN  590.423.4569  25-Jun-05
# 19          110         John       Chen     JCHEN  515.124.4269  28-Sep-05
# 21          112  Jose Manuel      Urman   JMURMAN  515.124.4469  07-Mar-06
# 23          114          Den   Raphaely  DRAPHEAL  515.127.4561  07-Dec-02
# ...

# %%
df[df["JOB_ID"] != "SH_CLERK"]
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-Aug-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-Jun-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-Jun-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-Jun-02
# 9           100       Steven         King     SKING  515.123.4567  17-Jun-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-Sep-05
# 11          102          Lex      De Haan   LDEHAAN  515.123.4569  13-Jan-01
# 12          103    Alexander       Hunold   AHUNOLD  590.423.4567  03-Jan-06
# ...

# %%
df[df["SALARY"]==2600]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198     Donald  OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1           199    Douglas     Grant    DGRANT  650.507.9844  13-Jan-08
# 27          118        Guy    Himuro   GHIMURO  515.127.4565  15-Nov-06
#
#       JOB_ID  SALARY MANAGER_ID  DEPARTMENT_ID  Unnamed: 11 gender
# 0   SH_CLERK    2600        124             50          NaN      f
# 1   SH_CLERK    2600        124             50          NaN      m
# 27  PU_CLERK    2600        114             30          NaN      m
